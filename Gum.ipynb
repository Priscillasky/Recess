# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.max_columns = 50
sns.set(style="darkgrid",rc={"axes.facecolor":"CAF1DE"})

# %%
df = pd.read_csv("data.csv")
df
# Out:
#     Unnamed: 0                                    Unnamed: 1 REPORTED CASES  \
# 0          NaN                                           NaN            NaN
# 1          NaN                                           NaN   Totals Cases
# 2        S/No.                         CASE/CRIME INCIDENCES              1
# 3          NaN                                     HOMICIDES            NaN
# 4            1                          Death  (by shooting)            190
# 5            2                         Death (by mob action)            636
# 6            3                             Death (Poisoning)             81
# 7            4          Death (Aggravated Domestic Violence)            362
# 8            5                        Death(Fire Out Breaks)             42
# 9            8             Other Death (Not Specified above)          3,186
# 10         NaN                          Sub Total(Homicides)          4,497
# ...

# %%
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  \
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# 122         98            UWA Statute            648        112         89
# 123         99   Local Government Act              4          2          1
# 124        100         All other Acts            821        345        189
# 125        NaN  Sub Total(Other Laws)          3,006        749        620
# 126        NaN            GRAND TOTAL        238,746     90,763     74,948
#
#     Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 122        447        485        269          8         26         144
# 123          1          1          -          -          -           1
# 124        287        430        173          7         19          93
# 125      1,637      1,885        991         24        127         500
# 126     73,035    101,116     22,263      1,248     11,121      38,411
#
#     PERSONS TAKEN TO COURT Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# ...

# %%
df.shape
# Out:
# (127, 38)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
#Checking for null values
print(df.isnull().sum())
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#     Unnamed: 0                                    Unnamed: 1 REPORTED CASES  \
# 4            1                          Death  (by shooting)            190
# 5            2                         Death (by mob action)            636
# 6            3                             Death (Poisoning)             81
# 7            4          Death (Aggravated Domestic Violence)            362
# 8            5                        Death(Fire Out Breaks)             42
# 9            8             Other Death (Not Specified above)          3,186
# 12           9                                  Embezzlement            199
# 13          10                       Causing Financial losss             58
# 14          11                               Abuse of office             50
# 15          12                                Counterfeiting            541
# 16          13             Forgeries & Uttering of Documents            898
# ...

# %%
new_df.rename(columns = {'Unnamed: 0':'Position','Unnamed: 1':'Cases','REPORTED CASES':'Total Cases','Unnamed: 3':'Cases Under Inquiry','Unnamed: 4':'Not Detected','Unnamed: 5':'Cases Taken',
                         'PERFORMANCE':'Cases Submitted','Unnamed: 7':'Cases with conviction','Unnamed: 8':'Cases with Acquittals',
                         'Unnamed: 9':'Cases Dismissed','Unnamed: 10':'Cases Pending','PERSONS TAKEN TO COURT':'Male Adult','Unnamed: 12':'Male Juven','Unnamed: 13':'Female Adult','Unnamed: 14':'Female Juven',
                        'Unnamed: 15':'Male Adult','Unnamed: 16':'Male Juven','Unnamed: 17':'Female Adult','Unnamed: 18':'Female Juven','Unnamed: 19':'Acquitted','Unnamed: 20':'Discharged','Unnamed: 21':'Awaiting Trial',
                         'SENTENCES IMPOSED BY COURTS':'Male Adults','Unnamed: 23':'Male Juven','Unnamed: 24':'Female Adult','Unnamed: 25':'Female Juven','Unnamed: 26':'Death','Unnamed: 27':'Fined','Unnamed: 28':'Probation',
                        'Unnamed: 29':'Caution','Unnamed: 30':'COMM WORK','Unnamed: 31':'Fines Awarded','Unnamed: 32':'Male Adult','Unnamed: 33':'Male Juven','Unnamed: 34':'Female Adult','Unnamed: 35':'Female Juven','Unnamed: 36':'Lost',
                        'Unnamed: 37':'Recovered'},inplace= True)
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/3851085715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns = {'Unnamed: 0':'Position','Unnamed: 1':'Cases','REPORTED CASES':'Total Cases','Unnamed: 3':'Cases Under Inquiry','Unnamed: 4':'Not Detected','Unnamed: 5':'Cases Taken',

# %%
new_df.rename( columns={'PERFOMANCE':'Cases submitted'}, inplace=True )
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/1550067630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename( columns={'PERFOMANCE':'Cases submitted'}, inplace=True )

# %%
new_df.head()
# Out:
#   Position                                 Cases Total Cases  \
# 4        1                  Death  (by shooting)         190
# 5        2                 Death (by mob action)         636
# 6        3                     Death (Poisoning)          81
# 7        4  Death (Aggravated Domestic Violence)         362
# 8        5                Death(Fire Out Breaks)          42
#
#   Cases Under Inquiry Not Detected Cases Taken Cases submitted  \
# 4                 117           29          44              74
# 5                 431          109          96             176
# 6                  54           12          15              17
# 7                 107           24         231             239
# 8                  25           11           6              14
#
#   Cases with conviction Cases with Acquittals Cases Dismissed Cases Pending  \
# 4                     3                     1               1            39
# ...

# %%
new_df.replace('-', 0, inplace=True)
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/238390352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.replace('-', 0, inplace=True)

# %%
new_df.head()
# Out:
#   Position                                 Cases Total Cases  \
# 4        1                  Death  (by shooting)         190
# 5        2                 Death (by mob action)         636
# 6        3                     Death (Poisoning)          81
# 7        4  Death (Aggravated Domestic Violence)         362
# 8        5                Death(Fire Out Breaks)          42
#
#   Cases Under Inquiry Not Detected Cases Taken Cases submitted  \
# 4                 117           29          44              74
# 5                 431          109          96             176
# 6                  54           12          15              17
# 7                 107           24         231             239
# 8                  25           11           6              14
#
#   Cases with conviction Cases with Acquittals Cases Dismissed Cases Pending  \
# 4                     3                     1               1            39
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_column',None)
new_df
# Out:
#     Position                                         Cases Total Cases  \
# 4          1                          Death  (by shooting)         190
# 5          2                         Death (by mob action)         636
# 6          3                             Death (Poisoning)          81
# 7          4          Death (Aggravated Domestic Violence)         362
# 8          5                        Death(Fire Out Breaks)          42
# 9          8             Other Death (Not Specified above)       3,186
# 12         9                                  Embezzlement         199
# 13        10                       Causing Financial losss          58
# 14        11                               Abuse of office          50
# 15        12                                Counterfeiting         541
# 16        13             Forgeries & Uttering of Documents         898
# 17        14                         Issuing False Cheques         344
# ...

# %%
new_df.duplicated()
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 28     False
# 29     False
# 30     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 67     False
# 68     False
# 69     False
# 70     False
# 72     False
# 75     False
# 76     False
# 77     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 98     False
# 99     False
# ...

# %%
new_df.drop_duplicates(inplace= True)
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/889757145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop_duplicates(inplace= True)

# %%
new_df.fillna(0, inplace=True)
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/2476780206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.fillna(0, inplace=True)

# %%
new_df.head()
# Out:
#   Position                                 Cases Total Cases  \
# 4        1                  Death  (by shooting)         190
# 5        2                 Death (by mob action)         636
# 6        3                     Death (Poisoning)          81
# 7        4  Death (Aggravated Domestic Violence)         362
# 8        5                Death(Fire Out Breaks)          42
#
#   Cases Under Inquiry Not Detected Cases Taken Cases submitted  \
# 4                 117           29          44              74
# 5                 431          109          96             176
# 6                  54           12          15              17
# 7                 107           24         231             239
# 8                  25           11           6              14
#
#   Cases with conviction Cases with Acquittals Cases Dismissed Cases Pending  \
# 4                     3                     1               1            39
# ...

# %%
new_df.dtypes
# Out:
# Position                 object
# Cases                    object
# Total Cases              object
# Cases Under Inquiry      object
# Not Detected             object
# Cases Taken              object
# Cases submitted          object
# Cases with conviction    object
# Cases with Acquittals    object
# Cases Dismissed          object
# Cases Pending            object
# Male Adult               object
# Male Juven               object
# Female Adult             object
# Female Juven             object
# Male Adult               object
# Male Juven               object
# Female Adult             object
# Female Juven             object
# Acquitted                object
# Discharged               object
# Awaiting Trial           object
# Male Adults              object
# Male Juven               object
# Female Adult             object
# Female Juven             object
# Death                     int64
# Fined                    object
# Probation                object
# ...

# %%
new_df.fillna(0)
# Out:
#     Position                                         Cases Total Cases  \
# 4          1                          Death  (by shooting)         190
# 5          2                         Death (by mob action)         636
# 6          3                             Death (Poisoning)          81
# 7          4          Death (Aggravated Domestic Violence)         362
# 8          5                        Death(Fire Out Breaks)          42
# 9          8             Other Death (Not Specified above)       3,186
# 12         9                                  Embezzlement         199
# 13        10                       Causing Financial losss          58
# 14        11                               Abuse of office          50
# 15        12                                Counterfeiting         541
# 16        13             Forgeries & Uttering of Documents         898
# 17        14                         Issuing False Cheques         344
# ...

# %%
new_df.replace(',', '', inplace=True)
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/943075968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.replace(',', '', inplace=True)

# %%
new_df
# Out:
#     Position                                         Cases Total Cases  \
# 4          1                          Death  (by shooting)         190
# 5          2                         Death (by mob action)         636
# 6          3                             Death (Poisoning)          81
# 7          4          Death (Aggravated Domestic Violence)         362
# 8          5                        Death(Fire Out Breaks)          42
# 9          8             Other Death (Not Specified above)       3,186
# 12         9                                  Embezzlement         199
# 13        10                       Causing Financial losss          58
# 14        11                               Abuse of office          50
# 15        12                                Counterfeiting         541
# 16        13             Forgeries & Uttering of Documents         898
# 17        14                         Issuing False Cheques         344
# ...

# %%
new_df = new_df.replace(',', '', regex=True)
new_df
# Out:
#     Position                                        Cases Total Cases  \
# 4          1                         Death  (by shooting)         190
# 5          2                        Death (by mob action)         636
# 6          3                            Death (Poisoning)          81
# 7          4         Death (Aggravated Domestic Violence)         362
# 8          5                       Death(Fire Out Breaks)          42
# 9          8            Other Death (Not Specified above)        3186
# 12         9                                 Embezzlement         199
# 13        10                      Causing Financial losss          58
# 14        11                              Abuse of office          50
# 15        12                               Counterfeiting         541
# 16        13            Forgeries & Uttering of Documents         898
# 17        14                        Issuing False Cheques         344
# ...

# %%
#for column in new_df.columns:
 #   if pd.api.types.is_numeric_dtype(new_df[column]):
  #      new_df[column] = new_df[column].apply(lambda x: abs(x) if pd.notnull(x) else x)#

# %%
new_df
# Out:
#     Position                                        Cases Total Cases  \
# 4          1                         Death  (by shooting)         190
# 5          2                        Death (by mob action)         636
# 6          3                            Death (Poisoning)          81
# 7          4         Death (Aggravated Domestic Violence)         362
# 8          5                       Death(Fire Out Breaks)          42
# 9          8            Other Death (Not Specified above)        3186
# 12         9                                 Embezzlement         199
# 13        10                      Causing Financial losss          58
# 14        11                              Abuse of office          50
# 15        12                               Counterfeiting         541
# 16        13            Forgeries & Uttering of Documents         898
# 17        14                        Issuing False Cheques         344
# ...

# %%
new_df = new_df.replace(',', '', regex=True)

# %%
new_df.dropna()
# Out:
#     Position                                        Cases  Total Cases  \
# 4          1                         Death  (by shooting)          190
# 5          2                        Death (by mob action)          636
# 6          3                            Death (Poisoning)           81
# 7          4         Death (Aggravated Domestic Violence)          362
# 8          5                       Death(Fire Out Breaks)           42
# 9          8            Other Death (Not Specified above)         3186
# 12         9                                 Embezzlement          199
# 13        10                      Causing Financial losss           58
# 14        11                              Abuse of office           50
# 15        12                               Counterfeiting          541
# 16        13            Forgeries & Uttering of Documents          898
# 17        14                        Issuing False Cheques          344
# ...

# %%
new_df.fillna(0)
# Out:
#     Position                                        Cases  Total Cases  \
# 4          1                         Death  (by shooting)          190
# 5          2                        Death (by mob action)          636
# 6          3                            Death (Poisoning)           81
# 7          4         Death (Aggravated Domestic Violence)          362
# 8          5                       Death(Fire Out Breaks)           42
# 9          8            Other Death (Not Specified above)         3186
# 12         9                                 Embezzlement          199
# 13        10                      Causing Financial losss           58
# 14        11                              Abuse of office           50
# 15        12                               Counterfeiting          541
# 16        13            Forgeries & Uttering of Documents          898
# 17        14                        Issuing False Cheques          344
# ...

# %%
column_name = 'Male Adults'

new_df.loc[new_df[column_name] < 0, column_name] = pd.NA
new_df
# Out:
#     Position                                        Cases  Total Cases  \
# 4          1                         Death  (by shooting)          190
# 5          2                        Death (by mob action)          636
# 6          3                            Death (Poisoning)           81
# 7          4         Death (Aggravated Domestic Violence)          362
# 8          5                       Death(Fire Out Breaks)           42
# 9          8            Other Death (Not Specified above)         3186
# 12         9                                 Embezzlement          199
# 13        10                      Causing Financial losss           58
# 14        11                              Abuse of office           50
# 15        12                               Counterfeiting          541
# 16        13            Forgeries & Uttering of Documents          898
# 17        14                        Issuing False Cheques          344
# ...

# %%
new_df.dropna()
# Out:
#     Position                                        Cases  Total Cases  \
# 4          1                         Death  (by shooting)          190
# 5          2                        Death (by mob action)          636
# 6          3                            Death (Poisoning)           81
# 7          4         Death (Aggravated Domestic Violence)          362
# 8          5                       Death(Fire Out Breaks)           42
# 9          8            Other Death (Not Specified above)         3186
# 12         9                                 Embezzlement          199
# 13        10                      Causing Financial losss           58
# 15        12                               Counterfeiting          541
# 16        13            Forgeries & Uttering of Documents          898
# 17        14                        Issuing False Cheques          344
# 18        15              Bank and Other Corporate Frauds           17
# ...

# %%
new_df['Total Cases'] = new_df['Total Cases'].astype(int)
new_df['Cases Under Inquiry'] = new_df['Cases Under Inquiry'].astype(int)
new_df['Not Detected'] = new_df['Not Detected'].astype(int)
new_df['Cases Taken'] = new_df['Cases Taken'].astype(int)
new_df['Cases submitted'] = new_df['Cases submitted'].astype(int)
new_df['Cases with conviction'] = new_df['Cases with conviction'].astype(int)
new_df['Cases with Acquittals'] = new_df['Cases with Acquittals'].astype(int)
new_df['Cases Dismissed'] = new_df['Cases Dismissed'].astype(int)
new_df['Cases Pending'] = new_df['Cases Pending'].astype(int)
new_df['Male Adult'] = new_df['Male Adult'].astype(int)
new_df['Male Juven'] = new_df['Male Juven'].astype(int)
new_df['Female Adult'] = new_df['Female Adult'].astype(int)
new_df['Female Juven'] = new_df['Female Juven'].astype(int)
new_df['Acquitted'] = new_df['Acquitted'].astype(int)
new_df['Discharged'] = new_df['Discharged'].astype(int)
new_df['Awaiting Trial'] = new_df['Awaiting Trial'].astype(int)

new_df['Fined'] = new_df['Fined'].astype(int)
new_df['Probation'] = new_df['Probation'].astype(int)
new_df['COMM WORK'] = new_df['COMM WORK'].astype(int)
new_df['Fines Awarded'] = new_df['Fines Awarded'].astype(int)
new_df['Lost'] = new_df['Lost'].astype(int)
new_df['Recovered'] = new_df['Recovered'].astype(int)

# %%
new_df.dtypes
# Out:
# Position                  object
# Cases                     object
# Total Cases                int64
# Cases Under Inquiry        int64
# Not Detected               int64
# Cases Taken                int64
# Cases submitted            int64
# Cases with conviction      int64
# Cases with Acquittals      int64
# Cases Dismissed            int64
# Cases Pending              int64
# Male Adult                 int64
# Male Juven                 int64
# Female Adult               int64
# Female Juven               int64
# Male Adult                 int64
# Male Juven                 int64
# Female Adult               int64
# Female Juven               int64
# Acquitted                  int64
# Discharged                 int64
# Awaiting Trial             int64
# Male Adults              float64
# Male Juven                 int64
# Female Adult               int64
# Female Juven               int64
# Death                      int64
# Fined                      int64
# ...

# %%
med= new_df['Lost'].median()
med
# Out:
# 21500000.0

# %%
mean = new_df['Lost'].mean()
mean
# Out:
# 5964671075.530121

# %%
new_df['Discharged'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
correlation_matrix = new_df.corr()
plt.figure(figsize=(20, 10))  # Adjust the figure size as desired
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_48921/2597905648.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = new_df.corr()

# %%
columns_for_heatmap = ['Total Cases', 'Cases Taken', 'Cases submitted', 'Cases Dismissed','Discharged','Fined']

# Subset the DataFrame to include only the selected columns
df_subset = new_df[columns_for_heatmap]

# Calculate the correlation matrix
correlation_matrix = df_subset.corr()

# Plot the correlation matrix heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")

# Display the graph
plt.show()

# %%
columns_to_plot = ['Total Cases', 'Cases Under Inquiry', 'Not Detected','Cases Taken']

subset = new_df[columns_to_plot]
plt.figure(figsize=(20, 10))  # Adjust the figure size as desired
sns.heatmap(subset, cmap='coolwarm')
plt.title('Heatmap')
plt.show()

# %%
columns_to_plot = ['Death', 'Probation']

# Plot the line graph
new_df.plot(x='Fined', y=columns_to_plot, kind='bar')

# Customize the graph (optional)
plt.title("Bar Graph")
plt.xlabel("Fined")
plt.ylabel("Value")

# Display the graph
plt.show()

# %%
#Statistics for data science
#descriptive Statistics ,Measure Central Tendency(Mean, mode,median)Measure dspersion(standard)
#Probability
#Modeling
#ML
#regression , classification, cluster, anomaly detection

#Python correlation
#use method corr() claculates correlation coefficient between all columns in the data frame
#Strong positive correlation 1 strong negative correlation -1
#Perfect correlation 1 Perfect negative correlation 1
#Good Correlation 0.93455 Good correlation above 0.5
#Bad correlation when is less than 0.5 can be 0.0000009757 
#i.e
df =pd.DataFrame({
    'x':[1,2,3,4,5],
    'y':[6,7,8,9,10],
    'z':[11,12,13,14,15]
})
correlation = df.corr()
print(correlation)
# Out:
#      x    y    z
# x  1.0  1.0  1.0
# y  1.0  1.0  1.0
# z  1.0  1.0  1.0
