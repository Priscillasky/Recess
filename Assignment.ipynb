# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mpl

pd.options.display.max_columns = 50
sns.set(style="darkgrid",rc={"axes.facecolor":"CAF1DE"})

# %%
df = pd.read_csv("sample.csv")
df
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
df.shape
# Out:
# (127, 38)

# %%
column_headers = df.columns
print(column_headers)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  \
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# 122         98            UWA Statute            648        112         89
# 123         99   Local Government Act              4          2          1
# 124        100         All other Acts            821        345        189
# 125        NaN  Sub Total(Other Laws)          3,006        749        620
# 126        NaN            GRAND TOTAL        238,746     90,763     74,948
#
#     Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 122        447        485        269          8         26         144
# 123          1          1          -          -          -           1
# 124        287        430        173          7         19          93
# 125      1,637      1,885        991         24        127         500
# 126     73,035    101,116     22,263      1,248     11,121      38,411
#
#     PERSONS TAKEN TO COURT Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0             Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4  \
# count          95                    125            125        125        125
# unique         95                    125            104         95         89
# top         S/No.  CASE/CRIME INCIDENCES              -          -          -
# freq            1                      1             17         18         24
#
#        Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# count         125        125        125        125        125         125
# unique         89         98         66         41         60          84
# top             -          -          -          -          -           -
# freq           20         19         34         55         39          20
#
#        PERSONS TAKEN TO COURT Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# count                     126         124         124         124         126
# ...

# %%
#Checking for null values
print(df.isnull().sum())
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
#naming unnamed columns
# Rename the unnamed columns with appropriate names
df.rename(columns={'Unnamed: 0':'POSITION','Unnamed: 1':'CASES','Unnamed: 3':'Total Cases','Unnamed: 4':'Cases Under Inquiry','Unnamed: 5':'Not Detected',
                  'Unnamed: 7':'Cases Taken to Court','Unnamed: 8':'Cases Submitted to DPF','Unnamed: 9':'Cases with convictions','Unnamed: 10':'Cases With Convictions',
                  'Unnamed: 12':'Cases with acquitals','Unnamed: 13':'Cases Dismissed','Unnamed: 14':'Pending in Court','Unnamed: 15':'ACCUSED CHARGED','Unnamed: 16':'POSITION'}, inplace=True)

# %%
df.columns
# Out:
# Index(['POSITION', 'CASES', 'REPORTED CASES', 'Total Cases', 'Not Detected',
#        'Not Detected', 'PERFOMANCE', 'Cases Taken to Court',
#        'Cases Submitted to DPF', 'Cases with convictions',
#        'Cases With Convictions', 'PERSONS TAKEN TO COURT',
#        'Cases with acquitals', 'Cases Dismissed', 'Pending in Court',
#        'ACCUSED CHARGED', 'POSITION', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37'],
#       dtype='object')

# %%
df.head()
# Out:
#   POSITION                                 CASES REPORTED CASES Total Cases  \
# 4        1                  Death  (by shooting)            190         117
# 5        2                 Death (by mob action)            636         431
# 6        3                     Death (Poisoning)             81          54
# 7        4  Death (Aggravated Domestic Violence)            362         107
# 8        5                Death(Fire Out Breaks)             42          25
#
#   Not Detected Not Detected PERFOMANCE Cases Taken to Court  \
# 4           29           44         74                    3
# 5          109           96        176                    2
# 6           12           15         17                    -
# 7           24          231        239                   15
# 8           11            6         14                    -
#
#   Cases Submitted to DPF Cases with convictions Cases With Convictions  \
# 4                      1                      1                     39
# ...

# %%
df.head()
# Out:
#   POSITION                                 CASES Total Cases Not Detected  \
# 4        1                  Death  (by shooting)         117           29
# 5        2                 Death (by mob action)         431          109
# 6        3                     Death (Poisoning)          54           12
# 7        4  Death (Aggravated Domestic Violence)         107           24
# 8        5                Death(Fire Out Breaks)          25           11
#
#   Not Detected PERFOMANCE Cases Taken to Court Cases Submitted to DPF  \
# 4           44         74                    3                      1
# 5           96        176                    2                      -
# 6           15         17                    -                      -
# 7          231        239                   15                      -
# 8            6         14                    -                      -
#
#   Cases with convictions Cases With Convictions PERSONS TAKEN TO COURT  \
# ...
