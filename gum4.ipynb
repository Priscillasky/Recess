# %%
import pandas as pd
import matplotlib.pyplot as mpl
import numpy as np
import seaborn as sns

pd.options.display.max_columns = 50
sns.set(style="darkgrid",rc={"axes.facecolor":"CAF1DE"})

# %%
df4 = pd.read_csv("bse_dataset4.csv")
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4.head
# Out:
# <bound method NDFrame.head of                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4.shape
# Out:
# (169, 15)

# %%
df4.tail
# Out:
# <bound method NDFrame.tail of                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4_new = df4.dropna()
df4_new
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4.fillna(value = 100, inplace=True)

# %%
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4['Calories'].fillna(100,inplace = True)

df4['Calories'].dtypes
# Out:
# dtype('float64')

# %%
#replace them using mean,median, mode
m= df4['Calories'].mean()
m
# Out:
# 367.7390532544379

# %%
df4.median()
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_1296/3254786010.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4.median()
# Age          21.0
# Duration     60.0
# Pulse       105.0
# Maxpulse    131.0
# dtype: float64

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_column',None)
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
df4.head()
# Out:
#              Timestamp         gender   Age  emotion   YOB  CGPA  \
# 0  05/07/2023 09:38:39           Male  21.0  Content  2002  4.22
# 1  05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100   8.9
# 2  05/07/2023 09:39:09        Female   20.0    Happy  2002  3.98
# 3  05/07/2023 09:39:12           Male  21.0    Happy  2003  4.37
# 4  05/07/2023 09:39:14         Female  21.0    Happy  2002  3.63
#
#   Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                      No                      No
# 1                                     Yes                     Yes
# 2                                      No                      No
# 3                                      No                      No
# 4                                      No                      No
#
#   Do you have Anxiety? Do you have Panic attack?  \
# 0                  Yes                       Yes
# 1                  Yes                       Yes
# ...

# %%
df4.shape
# Out:
# (169, 15)

# %%
df4["Calories"].head(27)
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    269.0
# 12    345.3
# 13    379.3
# 14    275.0
# 15    215.2
# 16    300.0
# 17      NaN
# 18    323.0
# 19    243.0
# 20    364.2
# 21    282.0
# 22    300.0
# 23    246.0
# 24    334.5
# 25    250.0
# 26    241.0
# Name: Calories, dtype: float64

# %%
df4['Calories'] = pd.to_numeric(df4['Calories'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Volumes/DATA/Anaconda/anaconda3/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df4['Calories'] = pd.to_numeric(df4['Calories'])
#
# File /Volumes/DATA/Anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
df4.mean()
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_1296/1527584861.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4.mean()
# Age          22.497006
# Duration     63.846154
# Pulse       107.449704
# Maxpulse    134.071006
# dtype: float64

# %%
df4['Calories'] = pd.to_numeric(df4['Calories'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Volumes/DATA/Anaconda/anaconda3/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df4['Calories'] = pd.to_numeric(df4['Calories'])
#
# File /Volumes/DATA/Anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
#Find the median
#Empty cells,wrong formats.wrong data , duplicate

med= df4['Calories'].median()
#df4 ['Calories'].fillna(med, inplace = True)
med
# Out:
# 310.2

# %%
print(med)
# Out:
# 317.85

# %%
#calculate mode of age
mo = df4_new['Age'].mode()
df4_new['Age'].fillna(mo, inplace = True)
mo
# Out:
# /var/folders/vv/zwxlp49d4k35xv_07n3rxf140000gn/T/ipykernel_1296/566953101.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_new['Age'].fillna(mo, inplace = True)
# 0    21.0
# Name: Age, dtype: float64

# %%
#Wrong formats row that is hard to analyze(NaN, )
#20230112
#NaN Row 5 contained NaN values and we filled with NaN values.
#df4["Timestamp"].fillna("05/07/2023 09:45:13", inplace= True)
#df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 #Wrong formats row that is hard to analyze(NaN, )
#       2 #20230112
#       3 #NaN Row 5 contained NaN values and we filled with NaN values.
# ----> 4 df4["Timestamp"].fillna("05/07/2023 09:45:13", inplace= True)
#       5 df4
#
# TypeError: 'function' object is not subscriptable

# %%
#Wrong data 60
#Wrong data 2199, 21.99
#Row 23,37 contained typo in data 23,2300 typo ,we changed from 2300 to 23
#for x in df4.index:
    #if df4.loc[x,"gender"] == "Marabou srock":
        #df4.drop(x,inplace= True)

# %%
# removing duplicates
#df4.drop_duplicates(inplace = True)

# %%
#print(df4.duplicated())

# %%
#Data visualisation ,plotting,matplotlib library(Heatmap,piechart,bargraph,lineplot,(Dotted,dashed))
#scatterplot library,histogram
import matplotlib.pyplot as plt 

df4['Age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df4['Age'].plot(kind = 'bar')
# Out:
# <Axes: >
